# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
import sys
sys.path.append("../") # go to parent dir

# %%
model = torch.load("/home/sms/vws/frappe/saved/test/sgd_64/20191022-1233.pt").to("cpu")
model.eval()
# Out:
# Tratt(
#   (body): Sequential(
#     (0): Conv2d(110, 110, kernel_size=(4, 4), stride=(1, 1))
#     (1): BatchNorm2d(110, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(110, 110, kernel_size=(3, 3), stride=(1, 1))
#     (5): BatchNorm2d(110, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(110, 110, kernel_size=(3, 3), stride=(1, 1))
#     (9): BatchNorm2d(110, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): MaxPool2d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#     (12): Conv2d(110, 110, kernel_size=(3, 3), stride=(1, 1))
#     (13): BatchNorm2d(110, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): ReLU()
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (16): Conv2d(110, 110, kernel_size=(2, 2), stride=(1, 1))
#     (17): BatchNorm2d(110, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (18): ReLU()
#     (19): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (neck): Sequential(
#     (0): Conv1d(1, 1, kernel_size=(3,), stride=(1,))
#     (1): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (head): Sequential(
#     (0): Linear(in_features=54, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=128, out_features=3, bias=True)
#   )
# )

# %%
def get_activation(activation, name):
    def hook(model, input, output):
        activation[name] = output.detach()
    return hook

# %%
x = np.fromfile(r"/home/sms/vws/frappe/saved/test/data/x_1.1.bin", dtype=np.float32)
x = np.fromfile(r"/home/sms/vws/frappe/saved/test/data/x_1.2.bin", dtype=np.float32)

#y = np.fromfile(r"/home/sms/vws/frappe/saved/ordinary/y.bin", dtype=np.float32)



X = torch.from_numpy(np.reshape(x, (1, 1, 110, 256, 256)))
#y = torch.from_numpy(np.reshape(y, (16, 3)))

# %%
activation = {}
model.body.register_forward_hook(get_activation(activation, 'body'))
output = model(X)
act = activation['body']
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-7-9cdbf3356009> in <module>
#       1 activation = {}
#       2 model.body.register_forward_hook(get_activation(activation, 'body'))
# ----> 3 output = model(X)
#       4 act = activation['body']
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# ~/vws/frappe/models/spatiotemporal.py in forward(self, x)
#      91         x = x.squeeze()
#      92
# ---> 93         x = self.body(x)
#      94         x = x.squeeze().unsqueeze(1)
#      95         x = self.neck(x)
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     341
#     342     def forward(self, input):
# --> 343         return self.conv2d_forward(input, self.weight)
#     344
#     345 class Conv3d(_ConvNd):
#
# ~/.conda/envs/torch/lib/python3.7/site-packages/torch/nn/modules/conv.py in conv2d_forward(self, input, weight)
#     338                             _pair(0), self.dilation, self.groups)
#     339         return F.conv2d(input, weight, self.bias, self.stride,
# --> 340                         self.padding, self.dilation, self.groups)
#     341
#     342     def forward(self, input):
#
# RuntimeError: Expected 4-dimensional input for 4-dimensional weight 110 110 4, but got 3-dimensional input of size [110, 256, 256] instead

# %%
curves = act.squeeze().numpy()

# %%
plt.plot(curves[3, :])

# %%
yhat = model(X)

# %%
plt.scatter(yhat[:,0].detach().numpy(), y[:,0].detach().numpy())
plt.plot(np.linspace(1,3), np.linspace(1,3))

# %%
# Out:
# torch.Size([16, 3])
